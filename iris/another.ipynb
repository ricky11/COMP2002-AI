# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # This is markdown
# - hello
# - world
# * sdfsdf

# %%
X = np.random.randn(200,2)
plt.scatter(X[:,0], X[:,1])

# %%
X[100:,:] += 8
plt.scatter(X[:,0],X[:,1])
C = np.concatenate((np.ones(100), np.zeros(100)))

# %%
def assign_to_cluster(X,C):
    """
    Given the data set X and the cluster centers
    C, identify which cluster center each data point belongs to.
    """
